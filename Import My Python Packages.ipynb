# %% [markdown]
# 1) Attach your Google Drive

# %% [markdown]
# 2) Install pandas profiling as the one included into colab does not work properly

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip

# %% [markdown]
# Restart the Runtime if needed !

# %% [markdown]
# 3) Run the lines below

# %%
import sys
py_file_location = "/content/drive/MyDrive/pythonlib"
if not py_file_location in sys.path:
  sys.path.append(py_file_location)

from sklearn.preprocessing import StandardScaler
from DatasetManager import DatasetManager as ds

# %% [markdown]
# # Tests

# %% [markdown]
# 4) Play & Enjoy :-)

# %%
myDataset = ds()
datafile = "/content/drive/MyDrive/Training/(Udemy) XAI/xai-series-master/data/healthcare-dataset-stroke-data.csv"
datafile = "/content/drive/MyDrive/Colab Notebooks/Météo/data/per_year/2018.csv"
myDataset.load_csv(filepath=datafile, cat_text_thresold=5)
#myDataset.set_colmltype_ignore(["id"])
myDataset.get_columnsinfos()
# Out:
#                       NaN Null     Type  ...    50%        75%    max
# Name                                     ...
# Unnamed: 0              0    0    int64  ...  182.0      273.0  371.0
# region                  0    0   object  ...    NaN        NaN    NaN
# day                     0    0   object  ...    NaN        NaN    NaN
# TempMax_Deg             0    0  float64  ...   16.0       23.0   36.0
# TempMin_Deg             4    4  float64  ...   13.0       19.0   31.0
# Wind_kmh                0    0  float64  ...   15.0       22.0   61.0
# Wet_percent             0    0  float64  ...   76.0  85.333333  100.0
# Visibility_km           0    0  float64  ...  9.875       10.0   10.0
# CloudCoverage_percent   0    0  float64  ...   37.0     62.375  100.0
#
# [9 rows x 16 columns]

# %%
myDataset.profile(minimal=False)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sc = StandardScaler()
ds_prepared = myDataset.prep() #scaler=sc)
ds_prepared
# Out:
#       gender_Female  gender_Male  gender_Other  ...  avg_glucose_level   bmi  stroke
# 0                 0            1             0  ...             228.69  36.6       1
# 1                 1            0             0  ...             202.21   0.0       1
# 2                 0            1             0  ...             105.92  32.5       1
# 3                 1            0             0  ...             171.23  34.4       1
# 4                 1            0             0  ...             174.12  24.0       1
# ...             ...          ...           ...  ...                ...   ...     ...
# 5105              1            0             0  ...              83.75   0.0       0
# 5106              1            0             0  ...             125.20  40.0       0
# 5107              1            0             0  ...              82.99  30.6       0
# 5108              0            1             0  ...             166.29  25.6       0
# ...

# %%
X_train, X_test, y_train, y_test = myDataset.get_data_split(ds_prepared, "stroke")
X_train, y_train = ds.randomoversample(ds_prepared, X_train, y_train)
# Out:
# (7794, 21)
